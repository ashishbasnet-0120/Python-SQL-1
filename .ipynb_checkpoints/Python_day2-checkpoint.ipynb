# %% [markdown]
# ### operators

# %% [markdown]
# #### Arithmetic operators
# ## ## +,-,*,/,**,//

# %%
print(8/3)
# Out:
# 2.6666666666666665

# %%
print(8//3) # gives quotient
# Out:
# 2

# %%
print(8%3) # gives remainder
# Out:
# 2

# %%
print(2**2)
# Out:
# 4

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ### relational operators

# %% [markdown]
# #### >,<,>=,<=,     !=  ,==

# %%
print(4==4)
# Out:
# True

# %%
print(4!=3)
# Out:
# True

# %%
## bitwise operator 
print(2&3)
# Out:
# 2

# %%
 print(2|3)
# Out:
# 3

# %%
 print(2^3)
# Out:
# 1

# %%
 print(~3)
# Out:
# -4

# %%
## right shift
print(4>>2)
# Out:
# 1

# %%
## left shift
print(5<<2)
# Out:
# 20

# %%
## left shift
print(5<<3)
# Out:
# 40

# %% [markdown]
# ## Assignment operator in python

# %%
x=5
print(x)
# Out:
# 5

# %%
x +=3
print(x)

# it is equals to like x+3
# Out:
# 8

# %% [markdown]
# ### Membership operator

# %%
print(8 not in [2,3,8,10])
# Out:
# False

# %%
print("A" in "Ashish")
# Out:
# True
